# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as st

# %%
test = pd.read_csv(r'/content/drive/MyDrive/Real World Analytics Challenge/male_players_football.csv', low_memory=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: give me the shape of data where fifa version is 23

test[test['fifa_version'] == 23].shape
# Out:
# (18533, 110)

# %%
# prompt: give me the shape of data where fifa version is 23 & 22


test[(test['fifa_version'] == 23) | (test['fifa_version'] == 22)].shape
# Out:
# (37772, 110)

# %%
# prompt: select 12500 random data where fifa version is 23 and put it in data_23

data_23 = test[test['fifa_version'] == 23].sample(n=18000)

# %%
data_23.shape
# Out:
# (18000, 110)

# %%
data_23.head()
# Out:
#         player_id                                      player_url  \
# 149207     186941              /player/186941/raphael-wolf/230002
# 155063     200134             /player/200134/robbie-benson/230002
# 154930     269491           /player/269491/carnejy-antoine/230002
# 143715     259377  /player/259377/yeremy-jesus-pino-santos/230002
# 155740     257822                 /player/257822/efe-tatli/230002
#
#         fifa_version  fifa_update fifa_update_date   short_name  \
# 149207            23            2       2022-09-26      R. Wolf
# 155063            23            2       2022-09-26    R. Benson
# 154930            23            2       2022-09-26   C. Antoine
# 143715            23            2       2022-09-26  Yeremy Pino
# 155740            23            2       2022-09-26     E. Tatlı
#
#                        long_name player_positions  overall  potential  ...  \
# 149207              Raphael Wolf               GK       68         68  ...
# ...

# %%
# prompt: now select the same data from test where fifa version is 22 as you have selected in data_23 with respect to player id. put the data in data_22

player_ids_23 = data_23['player_id'].tolist()
data_22 = test[(test['fifa_version'] == 22) & (test['player_id'].isin(player_ids_23))]

# %%
# prompt: number of player id in player_ids_23

len(player_ids_23)
# Out:
# 18000

# %%
data_22.shape
# Out:
# (12651, 110)

# %%
# prompt: there are 12630 data are in data_22. these are also present in data_23. i need only these 12630 data in data_23

player_ids_22 = data_22['player_id'].tolist()
data_23 = data_23[data_23['player_id'].isin(player_ids_22)]
data_23.shape
# Out:
# (12651, 110)

# %%
# prompt: merge data22 and data 23 to data_22_23

import pandas as pd
data_22_23 = pd.concat([data_22, data_23])

# %%
data_22_23['player_id'].nunique()
# Out:
# 12651

# %%
data_22_23.shape
# Out:
# (25302, 110)

# %%
# prompt: duplicate value count in data_22_23 in player id

data_22_23['player_id'].duplicated().sum()
# Out:
# 12651

# %%
# prompt: download excel file for data_22_23

data_22_23.to_excel('data_22_23.xlsx', index=False)
from google.colab import files
files.download('data_22_23.xlsx')

# %%
# prompt: delete these columns(player_url, fifa_update, fifa_update_date, long_name, dob, league_id, club_team_id, club_jersey_number, club_loaned_from, club_joined_date, club_contract_valid_until_year, nationality_id, nation_team_id, nation_position, nation_jersey_number, international_reputation, work_rate, body_type, real_face, release_clause_eur, player_tags, player_face_url)

data_22_23 = data_22_23.drop(['player_url', 'fifa_update', 'fifa_update_date', 'long_name',
                                'dob', 'league_id', 'club_team_id', 'club_jersey_number',
                                'club_loaned_from', 'club_joined_date', 'club_contract_valid_until_year',
                                'nationality_id', 'nation_team_id', 'nation_position', 'nation_jersey_number',
                                'international_reputation', 'work_rate', 'body_type', 'real_face',
                                'release_clause_eur', 'player_tags', 'player_face_url'], axis=1)

# %%
# prompt: delete these columns (ls, st, rs, lw, lf, cf, rf, rw, lam, cam, ram, lm, lcm, cm, rcm, rm, lwb, ldm, cdm, rdm, rwb, lb, lcb, cb, rcb, rb, gk)

data_22_23 = data_22_23.drop(['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk'], axis=1)

# %%
data_22_23.shape
# Out:
# (25302, 61)

# %%
# prompt: download data_22_23.xlsx' in excel

data_22_23.to_excel('data_22_23.xlsx', index=False)
from google.colab import files
files.download('data_22_23.xlsx')

# %%
# prompt: find number of rows where value_eur is null

data_22_23['value_eur'].isnull().sum()
# Out:
# 84

# %%
# prompt: remove these rows 84 rows where value_eur is null

data_22_23 = data_22_23.dropna(subset=['value_eur'])
data_22_23.shape
# Out:
# (25218, 61)

# %%
data_22_23['value_eur'].isnull().sum()
# Out:
# 0

# %%
# prompt: put 0 in every null value you found except player_traits column

import numpy as np
data_22_23 = data_22_23.fillna(0)
data_22_23['player_traits'] = data_22_23['player_traits'].replace(0, np.nan)

# %%
data_22_23.to_excel('data_22_23.xlsx', index=False)
from google.colab import files
files.download('data_22_23.xlsx')

# %%
# prompt: make null values in player_traits with "Not Available"

data_22_23['player_traits'] = data_22_23['player_traits'].fillna("Not Available")

# %%
data_22_23.to_excel('data_22_23.xlsx', index=False)
from google.colab import files
files.download('data_22_23.xlsx')

# %%
# prompt: max and min value for all columns where numeric value is true

data_22_23.describe()
# Out:
#            player_id  fifa_version       overall     potential     value_eur  \
# count   25218.000000  25218.000000  25218.000000  25218.000000  2.521800e+04
# mean   230296.153779     22.499802     67.318463     71.970299  3.689782e+06
# std     25451.639596      0.500010      6.639206      6.162744  8.994157e+06
# min      1179.000000     22.000000     46.000000     50.000000  1.500000e+04
# 25%    213662.000000     22.000000     63.000000     68.000000  6.000000e+05
# 50%    234582.000000     22.000000     67.000000     72.000000  1.200000e+06
# 75%    250948.000000     23.000000     72.000000     76.000000  2.600000e+06
# max    264631.000000     23.000000     93.000000     95.000000  1.940000e+08
#
#             wage_eur           age     height_cm     weight_kg  league_level  \
# count   25218.000000  25218.000000  25218.000000  25218.000000  25218.000000
# mean    11460.613451     25.595527    181.686018     75.306844      1.391308
# ...

# %%
# prompt: count unique club names

data_22_23['club_name'].nunique()
# Out:
# 1107

# %%
# prompt: download this data in csv file

data_22_23.to_csv('data_22_23.csv', index=False)
files.download('data_22_23.csv')

# %%
test = pd.read_csv(r'/content/drive/MyDrive/Real World Analytics Challenge/data_22_23_4.csv', low_memory=False)

# %%
test.shape
# Out:
# (25218, 61)
