# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as st

# %%
test = pd.read_csv(r'/content/drive/MyDrive/Real World Analytics Challenge/data_22_23_4.csv', low_memory=False)

# %%
test.shape
# Out:
# (25218, 61)

# %%
test.head()
# Out:
#    player_id  fifa_version         short_name player_positions  overall  \
# 0     158023            22           L. Messi       RW, ST, CF       93
# 1     188545            22     R. Lewandowski               ST       92
# 2      20801            22  Cristiano Ronaldo           ST, LW       91
# 3     190871            22          Neymar Jr          LW, CAM       91
# 4     192985            22       K. De Bruyne          CM, CAM       91
#
#    potential  value_eur  wage_eur  age  height_cm  ...  mentality_composure  \
# 0         93   78000000    320000   34        170  ...                   96
# 1         92  119500000    270000   32        185  ...                   88
# 2         91   45000000    270000   36        187  ...                   95
# 3         91  129000000    270000   29        175  ...                   93
# 4         91  125500000    350000   30        181  ...                   89
#
#   defending_marking_awareness  defending_standing_tackle  \
# ...

# %%
# prompt: number of null vaslues

test.isnull().sum()
# Out:
# player_id                  0
# fifa_version               0
# short_name                 0
# player_positions           0
# overall                    0
#                           ..
# goalkeeping_handling       0
# goalkeeping_kicking        0
# goalkeeping_positioning    0
# goalkeeping_reflexes       0
# goalkeeping_speed          0
# Length: 61, dtype: int64

# %%
# prompt: all columns are not showing. there is ... in between and they are hidden

#import pandas as pd
pd.set_option('display.max_columns', None)
test.head()
# Out:
#    player_id  fifa_version         short_name player_positions  overall  \
# 0     158023            22           L. Messi       RW, ST, CF       93
# 1     188545            22     R. Lewandowski               ST       92
# 2      20801            22  Cristiano Ronaldo           ST, LW       91
# 3     190871            22          Neymar Jr          LW, CAM       91
# 4     192985            22       K. De Bruyne          CM, CAM       91
#
#    potential  value_eur  wage_eur  age  height_cm  weight_kg     league_name  \
# 0         93   78000000    320000   34        170         72         Ligue 1
# 1         92  119500000    270000   32        185         81      Bundesliga
# 2         91   45000000    270000   36        187         83  Premier League
# 3         91  129000000    270000   29        175         68         Ligue 1
# 4         91  125500000    350000   30        181         70  Premier League
#
# ...

# %%
# prompt: number of null values. show all columns. there should not be any any hidden one

#import pandas as pd
pd.set_option('display.max_rows', None)
test.isnull().sum()
# Out:
# player_id                      0
# fifa_version                   0
# short_name                     0
# player_positions               0
# overall                        0
# potential                      0
# value_eur                      0
# wage_eur                       0
# age                            0
# height_cm                      0
# weight_kg                      0
# league_name                    0
# league_level                   0
# club_name                      0
# club_position                  0
# nationality_name               0
# preferred_foot                 0
# weak_foot                      0
# skill_moves                    0
# player_traits                  0
# pace                           0
# shooting                       0
# passing                        0
# dribbling                      0
# defending                      0
# physic                         0
# attacking_crossing             0
# attacking_finishing            0
# ...

# %%
# prompt: describe tha data through test.describe(). there should not be any hidden values

#import pandas as pd
pd.set_option('display.max_rows', None)
test.describe()
# Out:
#            player_id  fifa_version       overall     potential     value_eur  \
# count   25218.000000  25218.000000  25218.000000  25218.000000  2.521800e+04
# mean   230296.153779     22.499802     67.318463     71.970299  3.689782e+06
# std     25451.639596      0.500010      6.639206      6.162744  8.994157e+06
# min      1179.000000     22.000000     46.000000     50.000000  1.500000e+04
# 25%    213662.000000     22.000000     63.000000     68.000000  6.000000e+05
# 50%    234582.000000     22.000000     67.000000     72.000000  1.200000e+06
# 75%    250948.000000     23.000000     72.000000     76.000000  2.600000e+06
# max    264631.000000     23.000000     93.000000     95.000000  1.940000e+08
#
#             wage_eur           age     height_cm     weight_kg  league_level  \
# count   25218.000000  25218.000000  25218.000000  25218.000000  25218.000000
# mean    11460.613451     25.595527    181.686018     75.306844      1.391308
# ...

# %%
test2 = pd.read_csv(r'/content/drive/MyDrive/Real World Analytics Challenge/male_players_football.csv', low_memory=False)

# %%
# prompt: add a column to test from test2. coulmn name : player_face_url. Match with player id and fifa_version

# Merge the two DataFrames on 'player_id' and 'fifa_version'
test = test.merge(test2[['player_id', 'fifa_version', 'player_face_url']], on=['player_id', 'fifa_version'], how='left')

# %%
pd.set_option('display.max_columns', None)
test.head()
# Out:
#    player_id  fifa_version         short_name player_positions  overall  \
# 0     158023            22           L. Messi       RW, ST, CF       93
# 1     188545            22     R. Lewandowski               ST       92
# 2      20801            22  Cristiano Ronaldo           ST, LW       91
# 3     190871            22          Neymar Jr          LW, CAM       91
# 4     192985            22       K. De Bruyne          CM, CAM       91
#
#    potential  value_eur  wage_eur  age  height_cm  weight_kg     league_name  \
# 0         93   78000000    320000   34        170         72         Ligue 1
# 1         92  119500000    270000   32        185         81      Bundesliga
# 2         91   45000000    270000   36        187         83  Premier League
# 3         91  129000000    270000   29        175         68         Ligue 1
# 4         91  125500000    350000   30        181         70  Premier League
#
# ...

# %%
# prompt: download this excel file

from google.colab import files
test.to_excel('output.xlsx', index=False)
files.download('output.xlsx')

# %%
test = pd.read_csv(r'/content/drive/MyDrive/Real World Analytics Challenge/data_22_23_5.csv', low_memory=False)

# %%
test.head()
# Out:
#    player_id  fifa_version         short_name player_positions  overall  \
# 0     158023            22           L. Messi       RW, ST, CF       93
# 1     188545            22     R. Lewandowski               ST       92
# 2      20801            22  Cristiano Ronaldo           ST, LW       91
# 3     190871            22          Neymar Jr          LW, CAM       91
# 4     192985            22       K. De Bruyne          CM, CAM       91
#
#    potential  value_eur  wage_eur  age  height_cm  weight_kg     league_name  \
# 0         93   78000000    320000   34        170         72         Ligue 1
# 1         92  119500000    270000   32        185         81      Bundesliga
# 2         91   45000000    270000   36        187         83  Premier League
# 3         91  129000000    270000   29        175         68         Ligue 1
# 4         91  125500000    350000   30        181         70  Premier League
#
# ...

# %%
test.describe()
# Out:
#            player_id  fifa_version       overall     potential     value_eur  \
# count   25218.000000  25218.000000  25218.000000  25218.000000  2.521800e+04
# mean   230296.153779     22.499802     67.318463     71.970299  3.689782e+06
# std     25451.639596      0.500010      6.639206      6.162744  8.994157e+06
# min      1179.000000     22.000000     46.000000     50.000000  1.500000e+04
# 25%    213662.000000     22.000000     63.000000     68.000000  6.000000e+05
# 50%    234582.000000     22.000000     67.000000     72.000000  1.200000e+06
# 75%    250948.000000     23.000000     72.000000     76.000000  2.600000e+06
# max    264631.000000     23.000000     93.000000     95.000000  1.940000e+08
#
#             wage_eur           age     height_cm     weight_kg  league_level  \
# count   25218.000000  25218.000000  25218.000000  25218.000000  25218.000000
# mean    11460.613451     25.595527    181.686018     75.306844      1.391308
# ...
